# %%
import shutil
import json

# %%
basevals = {
    "eta_p": 0,
    "eta_mu": 0.0,
    "tau_p": 0.5,
    "tau_mu": 0.5,
    "alpha": 0.01,
    "B": 1.1,
    "epsilon": 1e-6,
    "itermax": 10000,
    "verbose": true,
    "tmax": 14400,
    "inner_iter": 5
}
for eps in range(2, 8):
    basevals["epsilon"] = 10**(-eps)
    with open(f"dual_extra{}")
